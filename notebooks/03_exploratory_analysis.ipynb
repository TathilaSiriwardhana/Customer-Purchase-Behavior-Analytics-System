# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/processed/customer_behavior_cleaned.csv")
df.head()
# Out:
#    customer_id  gender  age  estimated_salary  purchased purchase_status  \
# 0     15624510    Male   19             19000          0              No
# 1     15810944    Male   35             20000          0              No
# 2     15668575  Female   26             43000          0              No
# 3     15603246  Female   27             57000          0              No
# 4     15804002    Male   19             76000          0              No
#
#   age_group
# 0     18-25
# 1     26-35
# 2     26-35
# 3     26-35
# 4     18-25

# %% [markdown]
# ## Business Questions
#
# 1. Which age groups are most common among customers?
# 2. Do older customers spend more than younger customers?
# 3. What is the purchase frequency by age group?
# 4. Which customer segments are most valuable for the business?

# %%
df["age_group"].value_counts().sort_index()
# Out:
# age_group
# 18-25     44
# 26-35    129
# 36-45    119
# 46-60    103
# Name: count, dtype: int64

# %%
df.groupby("age_group")["purchase_amount"].mean().round(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.groupby("age_group")["purchase_amount"].mean().round(2)
#
# File e:\Projects\Customer Purchase Behavior Analytics System\.venv\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File e:\Projects\Customer Purchase Behavior Analytics System\.venv\Lib\site-packages\pandas\core\base.py:245, in SelectionMixin.__getitem__(self, key)
#     243 else:
#     244     if key not in self.obj:
# --> 245         raise KeyError(f"Column not found: {key}")
#     246     ndim = self.obj[key].ndim
#     247     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: purchase_amount'

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'estimated_salary', 'purchased',
#        'purchase_status', 'age_group'],
#       dtype='object')

# %%
df["age_group"].value_counts().sort_index()
# Out:
# age_group
# 18-25     44
# 26-35    129
# 36-45    119
# 46-60    103
# Name: count, dtype: int64

# %%
df.groupby("age_group")["purchased"].sum()
# Out:
# age_group
# 18-25     0
# 26-35    17
# 36-45    38
# 46-60    88
# Name: purchased, dtype: int64

# %%
df.groupby("age_group")["purchased"].mean().round(2)
# Out:
# age_group
# 18-25    0.00
# 26-35    0.13
# 36-45    0.32
# 46-60    0.85
# Name: purchased, dtype: float64

# %%
df.groupby("gender")["purchased"].sum()
df.groupby("gender")["purchased"].mean().round(2)
# Out:
# gender
# Female    0.38
# Male      0.34
# Name: purchased, dtype: float64

# %%
df.groupby("age_group")["estimated_salary"].mean().round(2)
# Out:
# age_group
# 18-25    54136.36
# 26-35    66790.70
# 36-45    75630.25
# 46-60    73466.02
# Name: estimated_salary, dtype: float64

# %%
pd.crosstab(df["age_group"], df["gender"], values=df["purchased"], aggfunc="mean").round(2)
# Out:
# gender     Female  Male
# age_group
# 18-25        0.00  0.00
# 26-35        0.14  0.12
# 36-45        0.30  0.33
# 46-60        0.84  0.88

# %%
df.to_csv("../data/processed/customer_behavior_final.csv", index=False)
